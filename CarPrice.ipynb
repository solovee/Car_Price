# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asinow/car-price-dataset")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/asinow/car-price-dataset?dataset_version_number=1...
# 100%|██████████| 135k/135k [00:00<00:00, 22.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/asinow/car-price-dataset/versions/1

# %%
from google.colab import files
files.upload()

# %%
# !kaggle datasets download -d asinow/car-price-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/asinow/car-price-dataset
# License(s): other
# Downloading car-price-dataset.zip to /content
#   0% 0.00/135k [00:00<?, ?B/s]
# 100% 135k/135k [00:00<00:00, 59.5MB/s]

# %%
# !unzip car-price-dataset.zip
# Out:
# Archive:  car-price-dataset.zip
#   inflating: car_price_dataset.csv

# %%
import pandas as pd
import tensorflow as tf
import numpy as np

df = pd.read_csv('car_price_dataset.csv')
df.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 10)

# %%
df_encoded = pd.get_dummies(df, columns=['Brand', 'Model', 'Fuel_Type', 'Transmission'])
df_encoded.head()
# Out:
#    Year  Engine_Size  Mileage  Doors  Owner_Count  Price  Brand_Audi  \
# 0  2020          4.2   289944      3            5   8501       False
# 1  2012          2.0     5356      2            3  12092       False
# 2  2020          4.2   231440      4            2  11171       False
# 3  2023          2.0   160971      2            1  11780        True
# 4  2003          2.6   286618      3            3   2867       False
#
#    Brand_BMW  Brand_Chevrolet  Brand_Ford  ...  Model_Tiguan  Model_Tucson  \
# 0      False            False       False  ...         False         False
# 1      False             True       False  ...         False         False
# 2      False            False       False  ...         False         False
# 3      False            False       False  ...         False         False
# 4      False            False       False  ...         False         False
#
#    Model_X5  Fuel_Type_Diesel  Fuel_Type_Electric  Fuel_Type_Hybrid  \
# 0     False              True               False             False
# 1     False             False               False              True
# 2     False              True               False             False
# 3     False             False                True             False
# 4     False             False               False              True
#
#    Fuel_Type_Petrol  Transmission_Automatic  Transmission_Manual  \
# 0             False                   False                 True
# 1             False                    True                False
# 2             False                    True                False
# 3             False                   False                 True
# 4             False                   False                False
#
#    Transmission_Semi-Automatic
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                         True
#
# [5 rows x 53 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
colunas_norm = ['Year', 'Engine_Size', 'Mileage', 'Doors', 'Owner_Count']
df_encoded[colunas_norm] = scaler.fit_transform(df_encoded[colunas_norm])
df_encoded.head()
# Out:
#        Year  Engine_Size   Mileage     Doors  Owner_Count  Price  Brand_Audi  \
# 0  0.869565         0.80  0.966648  0.333333         1.00   8501       False
# 1  0.521739         0.25  0.017775  0.000000         0.50  12092       False
# 2  0.869565         0.80  0.771584  0.666667         0.25  11171       False
# 3  1.000000         0.25  0.536626  0.000000         0.00  11780        True
# 4  0.130435         0.40  0.955558  0.333333         0.50   2867       False
#
#    Brand_BMW  Brand_Chevrolet  Brand_Ford  ...  Model_Tiguan  Model_Tucson  \
# 0      False            False       False  ...         False         False
# 1      False             True       False  ...         False         False
# 2      False            False       False  ...         False         False
# 3      False            False       False  ...         False         False
# 4      False            False       False  ...         False         False
#
#    Model_X5  Fuel_Type_Diesel  Fuel_Type_Electric  Fuel_Type_Hybrid  \
# 0     False              True               False             False
# 1     False             False               False              True
# 2     False              True               False             False
# 3     False             False                True             False
# 4     False             False               False              True
#
#    Fuel_Type_Petrol  Transmission_Automatic  Transmission_Manual  \
# 0             False                   False                 True
# 1             False                    True                False
# 2             False                    True                False
# 3             False                   False                 True
# 4             False                   False                False
#
#    Transmission_Semi-Automatic
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                         True
#
# [5 rows x 53 columns]

# %%
X_base = df_encoded.drop(['Price'], axis=1)
Y_base = df_encoded['Price']

# %%
df.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_base, Y_base, test_size=0.2, random_state=42)

# %%
X_test
# Out:
#           Year  Engine_Size   Mileage     Doors  Owner_Count  Brand_Audi  \
# 6252  0.217391        0.050  0.859340  1.000000         1.00       False
# 4684  0.565217        0.475  0.372647  1.000000         0.50       False
# 1731  0.478261        1.000  0.044838  1.000000         0.75       False
# 4742  0.304348        0.700  0.444359  0.666667         1.00       False
# 4521  0.521739        0.075  0.061969  0.333333         1.00       False
# ...        ...          ...       ...       ...          ...         ...
# 6412  0.086957        0.750  0.669901  0.000000         1.00       False
# 8285  0.739130        0.475  0.043381  0.666667         0.50        True
# 7853  0.217391        0.700  0.462560  0.000000         0.00       False
# 1095  0.260870        0.525  0.631904  0.000000         1.00       False
# 6929  0.478261        0.625  0.257360  0.666667         1.00       False
#
#       Brand_BMW  Brand_Chevrolet  Brand_Ford  Brand_Honda  ...  Model_Tiguan  \
# 6252       True            False       False        False  ...         False
# 4684      False            False       False        False  ...         False
# 1731      False            False       False        False  ...         False
# 4742      False            False       False        False  ...         False
# 4521      False            False       False         True  ...         False
# ...         ...              ...         ...          ...  ...           ...
# 6412      False            False       False        False  ...          True
# 8285      False            False       False        False  ...         False
# 7853      False            False       False        False  ...         False
# 1095      False             True       False        False  ...         False
# 6929      False            False       False        False  ...         False
#
#       Model_Tucson  Model_X5  Fuel_Type_Diesel  Fuel_Type_Electric  \
# 6252         False     False              True               False
# 4684         False     False             False               False
# 1731         False     False             False               False
# 4742         False     False              True               False
# 4521         False     False             False               False
# ...            ...       ...               ...                 ...
# 6412         False     False              True               False
# 8285         False     False             False               False
# 7853         False     False              True               False
# 1095         False     False             False               False
# 6929         False     False             False               False
#
#       Fuel_Type_Hybrid  Fuel_Type_Petrol  Transmission_Automatic  \
# 6252             False             False                   False
# 4684              True             False                    True
# 1731              True             False                    True
# 4742             False             False                   False
# 4521             False              True                    True
# ...                ...               ...                     ...
# 6412             False             False                   False
# 8285              True             False                   False
# 7853             False             False                    True
# 1095             False              True                    True
# 6929              True             False                    True
#
#       Transmission_Manual  Transmission_Semi-Automatic
# 6252                 True                        False
# 4684                False                        False
# 1731                False                        False
# 4742                 True                        False
# 4521                False                        False
# ...                   ...                          ...
# 6412                 True                        False
# 8285                False                         True
# 7853                False                        False
# 1095                False                        False
# 6929                False                        False
#
# [2000 rows x 52 columns]

# %%
modelo1 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

modelo1.compile(optimizer='Adam', loss= tf.keras.losses.MeanSquaredError(), metrics=['mae'])

modelo1.fit(X_base, Y_base, epochs=100)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 77650752.0000 - mae: 8132.0317
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8240823.5000 - mae: 2350.2410
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5680064.5000 - mae: 1951.7413
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3586064.5000 - mae: 1550.5959
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1631856.8750 - mae: 1041.5637
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 404419.9688 - mae: 514.8523
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 46659.7109 - mae: 173.8027
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5925.9312 - mae: 53.2759
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3093.3687 - mae: 22.5841
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2430.2417 - mae: 14.1207
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2309.2512 - mae: 12.1445
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1925.5714 - mae: 10.6263
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2541.0381 - mae: 11.8747
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2546.7351 - mae: 11.3799
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1710.1143 - mae: 10.9152
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1683.2008 - mae: 10.2071
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1476.6000 - mae: 10.6159
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2198.9265 - mae: 11.1250
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1514.1075 - mae: 10.9142
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1617.9664 - mae: 11.0906
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1969.0830 - mae: 11.7910
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1207.6201 - mae: 9.9562
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 973.1250 - mae: 9.1932
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1132.6681 - mae: 10.0244
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 995.2493 - mae: 9.5733
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1103.6943 - mae: 10.4605
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 753.5058 - mae: 9.0843
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1076.9020 - mae: 10.4519
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 888.2780 - mae: 9.1604
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 771.4186 - mae: 10.0316
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 730.9390 - mae: 9.5866
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 569.4436 - mae: 8.8576
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 832.1505 - mae: 9.9142
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 527.9161 - mae: 8.2053
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 538.7531 - mae: 9.2875
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 592.4504 - mae: 9.3152
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 452.9542 - mae: 8.2377
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 434.8590 - mae: 8.2770
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 516.3911 - mae: 9.7956
# Epoch 40/100
# 206/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 317.3327 - mae: 8.0596

# %%
modelo1.evaluate(X_test, y_test, verbose=0)

# %%
arr = modelo1.predict(X_test)
arr[2], y_test.iloc[2]

# %%
import matplotlib.pyplot as plt

def plot_random_predictions_vs_real(X_test, y_test, modelo1):
    if len(X_test) < 5:
        print("Não há amostras suficientes para selecionar aleatoriamente 5.")
        return

    random_samples = X_test.sample(n=5)
    random_indices = random_samples.index

    X_sample = X_test.loc[random_indices]
    y_real = y_test.loc[random_indices]
    y_pred = modelo1.predict(X_sample)

    plt.figure(figsize=(10, 5))
    plt.scatter(random_indices, y_real, color='blue', label='Valores Reais', s=100)
    plt.scatter(random_indices, y_pred, color='red', label='Previsões', alpha=0.7, s=100)

    plt.xlabel('Índice da amostra')
    plt.ylabel('Valores')
    plt.title('Previsões vs Valores Reais para 5 carros Aleatórios')
    plt.legend()
    plt.grid(True)

    plt.show()

# %%
plot_random_predictions_vs_real(X_test, y_test, modelo1)

# %%
np.unique(df['Model'])
